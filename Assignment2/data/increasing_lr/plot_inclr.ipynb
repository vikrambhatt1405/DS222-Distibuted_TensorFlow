# %%
y_test[:100]
# Out:
# [14.145209312438965,
#  10.01030158996582,
#  7.512232780456543,
#  5.9294352531433105,
#  4.877041339874268,
#  4.181857109069824,
#  3.714010715484619,
#  3.396116256713867,
#  3.1820015907287598,
#  3.0494771003723145,
#  2.9516372680664062,
#  2.880040407180786,
#  2.8305273056030273,
#  2.791642189025879,
#  2.759544610977173,
#  2.7455496788024902,
#  2.7359089851379395,
#  2.7353553771972656,
#  2.714998960494995,
#  2.7094616889953613,
#  2.701158046722412,
#  2.694391965866089,
#  2.6974644660949707,
#  2.6991653442382812,
#  2.692209243774414,
#  2.6864211559295654,
#  2.690706491470337,
#  2.6838324069976807,
#  2.6837663650512695,
#  2.691037893295288,
#  2.681119203567505,
#  2.679349660873413,
#  2.6879115104675293,
#  2.6799890995025635,
#  2.6768622398376465,
#  2.6711037158966064,
#  2.6802432537078857,
#  2.6773762702941895,
#  2.6686689853668213,
#  2.67474627494812,
#  2.6701040267944336,
#  2.662959575653076,
#  2.6680729389190674,
#  2.663466691970825,
# ...

# %%
import matplotlib.pyplot as plt
import csv
f=plt.figure()

x_devel = []
y_devel = []

with open('run_devel-tag-logistic_regression_train_Cross_Entropy_Loss.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    next(plots,None)
    for row in plots:
        x_devel.append(float(row[1]))
        y_devel.append(float(row[2]))
x_test = []
y_test = []

with open('run_test-tag-logistic_regression_train_Cross_Entropy_Loss.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    next(plots,None)
    for row in plots:
        x_test.append(float(row[1]))
        y_test.append(float(row[2]))
y_train = []
x_train=[]
with open('run_train-tag-logistic_regression_train_Cross_Entropy_Loss.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    next(plots,None)
    for row in plots:
        x_train.append(float(row[1]))
        y_train.append(float(row[2]))
print(len(x_test))
print(len(x_train))
print(len(x_devel))
plt.plot(x_devel[:100],y_devel[:100],label='Developlment set loss')
plt.plot(x_test[:100],y_test[:100],label='Test set loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss vs epochs')
plt.legend()
f.savefig("inclr_train.pdf",bbox_inches='tight')
# Out:
# 971
# 11
# 971

# %%
import matplotlib.pyplot as plt
import csv
f=plt.figure()

x_devel = []
y_devel = []

with open('run_devel-tag-logistic_regression_train_Learning_Rate.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    next(plots,None)
    for row in plots:
        x_devel.append(float(row[1]))
        y_devel.append(float(row[2]))
x_test = []
y_test = []

with open('run_train-tag-logistic_regression_train_Learning_Rate.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    next(plots,None)
    for row in plots:
        x_test.append(float(row[1]))
        y_test.append(float(row[2]))

plt.plot(x_devel,y_devel,label='Learning rate step wise')
plt.plot(x_test,y_test,label='Learning rate continous')

plt.xlabel('Epochs')
plt.ylabel('Learning rate')
plt.title('Learning rate vs epochs')
plt.legend()
f.savefig("inclr.pdf",bbox_inches='tight')
