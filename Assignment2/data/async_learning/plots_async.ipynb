# %%
import matplotlib.pyplot as plt
import csv
f=plt.figure()

x_devel = []
y_devel = []

with open('run_worker0_.-tag-logistic_regression_train_Cross_Entropy_Loss.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    next(plots,None)
    for row in plots:
        x_devel.append(float(row[1]))
        y_devel.append(float(row[2]))
x_test = []
y_test = []

with open('run_worker1_.-tag-logistic_regression_train_Cross_Entropy_Loss.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    next(plots,None)
    for row in plots:
        x_test.append(float(row[1]))
        y_test.append(float(row[2]))
y_train = []
x_train=[]
with open('run_worker0_test-tag-logistic_regression_train_Cross_Entropy_Loss.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    next(plots,None)
    for row in plots:
        x_train.append(float(row[1]))
        y_train.append(float(row[2]))
        
y_val = []
x_val=[]
with open('run_worker1_test-tag-logistic_regression_train_Cross_Entropy_Loss.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    next(plots,None)
    for row in plots:
        x_val.append(float(row[1]))
        y_val.append(float(row[2]))
plt.plot(x_devel,y_devel,label='Worker0 Train Loss')
plt.plot(x_test,y_test,label='Worker1 Train Loss')
plt.plot(x_train,y_train,label='Worker0 Test Loss')
plt.plot(x_val,y_val,label='Worker1 Test Loss')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss vs epochs')
plt.legend()
f.savefig("async_train.pdf",bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import numpy as np
import csv
f=plt.figure()

x_devel = []
y_devel = []

with open('run_worker0_.-tag-logistic_regression_train_Cross_Entropy_Loss.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    next(plots,None)
    for row in plots:
        x_devel.append(float(row[0]))
        y_devel.append(float(row[2]))
x_test = []
y_test = []

with open('run_worker1_.-tag-logistic_regression_train_Cross_Entropy_Loss.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    next(plots,None)
    for row in plots:
        x_test.append(float(row[0]))
        y_test.append(float(row[2]))
print(len(x_test))#.shape)
print(len(x_devel))#.shape)
delays=np.array(x_test)-np.array(x_devel)
plt.plot(range(113),np.max(delays)-delays,label='Delays between two workers')
plt.xlabel('Epochs')
plt.ylabel('Delays(on wall clock time)')
plt.title('Epochs vs Delays')
plt.legend()
f.savefig('delays_async.pdf',bbox_inches='tight')
# Out:
# 113
# 113

# %%
plt.plot(x_devel,y_devel,label='Learning rate step wise')
plt.plot(x_test,y_test,label='Learning rate continous')

plt.xlabel('Epochs')
plt.ylabel('Learning rate')
plt.title('Learning rate vs epochs')
plt.legend()
f.savefig("declr.pdf",bbox_inches='tight')
